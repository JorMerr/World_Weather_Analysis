# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import gmaps
import time
from datetime import datetime

# import API key variables
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude coordinates.
lats = np.random.uniform(low= -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low= -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Create a list of latitude and longitude pairs.
coordinates = list(lat_lngs)

# Create a list for holding cities.
cities = []
# identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Base URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empoty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval ")
print("-------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | kwinana
# Processing Record 2 of Set 1 | vaitape
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | sharjah
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | marsh harbour
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | lavrentiya
# Processing Record 11 of Set 1 | sao jose da coroa grande
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | hot springs
# Processing Record 14 of Set 1 | shingu
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | gidole
# Processing Record 17 of Set 1 | santa cruz
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | komsomolskiy
# Processing Record 21 of Set 1 | oistins
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | madarounfa
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | maniitsoq
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | kijang
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | sao filipe
# Processing Record 36 of Set 1 | aklavik
# Processing Record 37 of Set 1 | malard
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | vaasa
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | zarautz
# Processing Record 42 of Set 1 | iowa city
# Processing Record 43 of Set 1 | nabire
# Processing Record 44 of Set 1 | margate
# Processing Record 45 of Set 1 | manaia
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | linhares
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | sabana grande de boya
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | panaba
# Processing Record 4 of Set 2 | nemuro
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | tatawin
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | asfi
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | casa nova
# Processing Record 11 of Set 2 | alofi
# Processing Record 12 of Set 2 | bonito
# Processing Record 13 of Set 2 | evanston
# Processing Record 14 of Set 2 | bac lieu
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | lianzhou
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | koutsouras
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | lieksa
# Processing Record 24 of Set 2 | saint-joseph
# Processing Record 25 of Set 2 | bad salzuflen
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | ust-maya
# Processing Record 29 of Set 2 | kambove
# Processing Record 30 of Set 2 | mareeba
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | vila velha
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | camopi
# Processing Record 39 of Set 2 | klyuchi
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | marsa matruh
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | trogir
# Processing Record 45 of Set 2 | sao felix do xingu
# Processing Record 46 of Set 2 | wasilla
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | fevik
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | novovarshavka
# Processing Record 4 of Set 3 | peru
# Processing Record 5 of Set 3 | lasa
# Processing Record 6 of Set 3 | bay roberts
# Processing Record 7 of Set 3 | santiago del estero
# Processing Record 8 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 3 | batagay
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | semporna
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | shasta lake
# Processing Record 14 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 3 | masvingo
# Processing Record 17 of Set 3 | sioux lookout
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | padang
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | hendijan
# City not found. Skipping...
# Processing Record 24 of Set 3 | merrill
# Processing Record 25 of Set 3 | asyut
# Processing Record 26 of Set 3 | brownsville
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | udachnyy
# Processing Record 29 of Set 3 | beira
# Processing Record 30 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 3 | gamba
# Processing Record 32 of Set 3 | ryabovo
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | la rioja
# Processing Record 35 of Set 3 | kongolo
# Processing Record 36 of Set 3 | manadhoo
# Processing Record 37 of Set 3 | omsukchan
# Processing Record 38 of Set 3 | anadyr
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | sonkovo
# Processing Record 41 of Set 3 | qaanaaq
# Processing Record 42 of Set 3 | hay river
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | uglovskoye
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | hakkari
# Processing Record 1 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | faranah
# Processing Record 6 of Set 4 | xichang
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 4 | north battleford
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | lavras
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | kabare
# Processing Record 16 of Set 4 | santarem
# Processing Record 17 of Set 4 | ardalstangen
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | atuona
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | buala
# Processing Record 23 of Set 4 | yagunovskiy
# Processing Record 24 of Set 4 | maragogi
# Processing Record 25 of Set 4 | connersville
# Processing Record 26 of Set 4 | evensk
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | ambatondrazaka
# Processing Record 29 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 4 | tahta
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | kinshasa
# Processing Record 33 of Set 4 | vestmanna
# Processing Record 34 of Set 4 | malmesbury
# Processing Record 35 of Set 4 | sayyan
# Processing Record 36 of Set 4 | novikovo
# Processing Record 37 of Set 4 | wanning
# Processing Record 38 of Set 4 | viedma
# Processing Record 39 of Set 4 | west wendover
# Processing Record 40 of Set 4 | clyde river
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | velyka bahachka
# Processing Record 44 of Set 4 | vanavara
# Processing Record 45 of Set 4 | kikwit
# Processing Record 46 of Set 4 | ilulissat
# Processing Record 47 of Set 4 | beringovskiy
# Processing Record 48 of Set 4 | sistranda
# Processing Record 49 of Set 4 | grand gaube
# Processing Record 50 of Set 4 | grand-lahou
# Processing Record 1 of Set 5 | tual
# Processing Record 2 of Set 5 | pimentel
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | jacareacanga
# Processing Record 6 of Set 5 | zachepylivka
# Processing Record 7 of Set 5 | lovington
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | thaba-tseka
# Processing Record 10 of Set 5 | rio gallegos
# Processing Record 11 of Set 5 | la cruz
# Processing Record 12 of Set 5 | urucara
# Processing Record 13 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | muzhi
# Processing Record 18 of Set 5 | cockburn town
# Processing Record 19 of Set 5 | vreed en hoop
# City not found. Skipping...
# Processing Record 20 of Set 5 | mandurah
# Processing Record 21 of Set 5 | hatillo
# Processing Record 22 of Set 5 | atasu
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | belmonte
# Processing Record 27 of Set 5 | goderich
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | srednekolymsk
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | talaya
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | kenora
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | vestmannaeyjar
# Processing Record 36 of Set 5 | male
# Processing Record 37 of Set 5 | oranjemund
# Processing Record 38 of Set 5 | coahuayana
# Processing Record 39 of Set 5 | nalut
# Processing Record 40 of Set 5 | grand forks
# Processing Record 41 of Set 5 | laguna
# Processing Record 42 of Set 5 | ambon
# Processing Record 43 of Set 5 | rio cuarto
# Processing Record 44 of Set 5 | healdsburg
# Processing Record 45 of Set 5 | jumla
# Processing Record 46 of Set 5 | dalbandin
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | bull savanna
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 6 | cherrapunji
# Processing Record 3 of Set 6 | breves
# Processing Record 4 of Set 6 | jaciara
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | seydi
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | zaykovo
# Processing Record 9 of Set 6 | jiuquan
# Processing Record 10 of Set 6 | krasnoarmeysk
# Processing Record 11 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 6 | leninskoye
# Processing Record 13 of Set 6 | bilma
# Processing Record 14 of Set 6 | opotiki
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | yar-sale
# Processing Record 17 of Set 6 | moree
# Processing Record 18 of Set 6 | sumbe
# Processing Record 19 of Set 6 | igbo ora
# Processing Record 20 of Set 6 | maldonado
# Processing Record 21 of Set 6 | juneau
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | tommot
# Processing Record 24 of Set 6 | kerema
# Processing Record 25 of Set 6 | hwange
# Processing Record 26 of Set 6 | port-gentil
# Processing Record 27 of Set 6 | havelock
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | nuuk
# Processing Record 30 of Set 6 | vanimo
# Processing Record 31 of Set 6 | palana
# Processing Record 32 of Set 6 | zabolotovka
# Processing Record 33 of Set 6 | sorong
# Processing Record 34 of Set 6 | americus
# Processing Record 35 of Set 6 | santo tomas
# Processing Record 36 of Set 6 | enid
# Processing Record 37 of Set 6 | sitka
# Processing Record 38 of Set 6 | orillia
# Processing Record 39 of Set 6 | christchurch
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | castro
# Processing Record 42 of Set 6 | phalodi
# Processing Record 43 of Set 6 | cururupu
# Processing Record 44 of Set 6 | talcahuano
# Processing Record 45 of Set 6 | mezen
# Processing Record 46 of Set 6 | bonavista
# Processing Record 47 of Set 6 | neryungri
# Processing Record 48 of Set 6 | raisen
# Processing Record 49 of Set 6 | tiarei
# Processing Record 50 of Set 6 | tazovskiy
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | denpasar
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | ushumun
# Processing Record 5 of Set 7 | mahebourg
# Processing Record 6 of Set 7 | hachinohe
# Processing Record 7 of Set 7 | yerbogachen
# Processing Record 8 of Set 7 | bima
# Processing Record 9 of Set 7 | nadym
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | iquitos
# Processing Record 12 of Set 7 | verdalsora
# City not found. Skipping...
# Processing Record 13 of Set 7 | richards bay
# Processing Record 14 of Set 7 | noshiro
# Processing Record 15 of Set 7 | burnie
# Processing Record 16 of Set 7 | sobolevo
# Processing Record 17 of Set 7 | kirakira
# Processing Record 18 of Set 7 | abu dhabi
# Processing Record 19 of Set 7 | inverell
# Processing Record 20 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 21 of Set 7 | usinsk
# Processing Record 22 of Set 7 | qaqortoq
# Processing Record 23 of Set 7 | ciudad guayana
# Processing Record 24 of Set 7 | laela
# Processing Record 25 of Set 7 | trincomalee
# Processing Record 26 of Set 7 | nicoya
# Processing Record 27 of Set 7 | spencer
# Processing Record 28 of Set 7 | stokmarknes
# Processing Record 29 of Set 7 | port hedland
# Processing Record 30 of Set 7 | mahon
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | salinopolis
# Processing Record 35 of Set 7 | svetlaya
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | katsuura
# Processing Record 38 of Set 7 | severo-kurilsk
# Processing Record 39 of Set 7 | boca do acre
# Processing Record 40 of Set 7 | inhambane
# Processing Record 41 of Set 7 | sambava
# Processing Record 42 of Set 7 | tigil
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | fukue
# Processing Record 45 of Set 7 | arona
# Processing Record 46 of Set 7 | changji
# Processing Record 47 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 7 | shulan
# Processing Record 49 of Set 7 | saint anthony
# Processing Record 50 of Set 7 | jinzhou
# Processing Record 1 of Set 8 | san-pedro
# Processing Record 2 of Set 8 | rundu
# Processing Record 3 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | turtas
# Processing Record 6 of Set 8 | nelson bay
# Processing Record 7 of Set 8 | hasaki
# Processing Record 8 of Set 8 | tera
# Processing Record 9 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 8 | macau
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | mayma
# Processing Record 13 of Set 8 | zhuanghe
# Processing Record 14 of Set 8 | harlingen
# Processing Record 15 of Set 8 | luau
# Processing Record 16 of Set 8 | tadine
# Processing Record 17 of Set 8 | kodiak
# Processing Record 18 of Set 8 | svetlyy
# Processing Record 19 of Set 8 | lethem
# Processing Record 20 of Set 8 | bethel
# Processing Record 21 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 22 of Set 8 | mayo
# Processing Record 23 of Set 8 | kristiinankaupunki
# Processing Record 24 of Set 8 | roma
# Processing Record 25 of Set 8 | jeremoabo
# Processing Record 26 of Set 8 | westport
# Processing Record 27 of Set 8 | sibolga
# Processing Record 28 of Set 8 | magadan
# Processing Record 29 of Set 8 | farmington
# Processing Record 30 of Set 8 | mogosesti-siret
# Processing Record 31 of Set 8 | chapais
# Processing Record 32 of Set 8 | darlowo
# Processing Record 33 of Set 8 | saint-pierre
# Processing Record 34 of Set 8 | elat
# Processing Record 35 of Set 8 | iralaya
# Processing Record 36 of Set 8 | kondinskoye
# Processing Record 37 of Set 8 | ambunti
# Processing Record 38 of Set 8 | shache
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | joao monlevade
# Processing Record 42 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 8 | ulaangom
# Processing Record 44 of Set 8 | araouane
# Processing Record 45 of Set 8 | gravdal
# Processing Record 46 of Set 8 | te anau
# Processing Record 47 of Set 8 | masyaf
# Processing Record 48 of Set 8 | kirksville
# Processing Record 49 of Set 8 | boa vista
# Processing Record 50 of Set 8 | poplar bluff
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 9 | kavaratti
# Processing Record 4 of Set 9 | hirara
# Processing Record 5 of Set 9 | taltal
# Processing Record 6 of Set 9 | la grande
# Processing Record 7 of Set 9 | jaltenango
# Processing Record 8 of Set 9 | general roca
# Processing Record 9 of Set 9 | sao miguel do araguaia
# Processing Record 10 of Set 9 | munirabad
# Processing Record 11 of Set 9 | sterling
# Processing Record 12 of Set 9 | katobu
# Processing Record 13 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 9 | hundested
# Processing Record 15 of Set 9 | kieta
# Processing Record 16 of Set 9 | upernavik
# Processing Record 17 of Set 9 | pudozh
# Processing Record 18 of Set 9 | lebu
# Processing Record 19 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 20 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | altay
# Processing Record 23 of Set 9 | shirokiy
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | baiao
# Processing Record 26 of Set 9 | tabory
# Processing Record 27 of Set 9 | imbituba
# Processing Record 28 of Set 9 | bandarbeyla
# Processing Record 29 of Set 9 | jidong
# Processing Record 30 of Set 9 | saint george
# Processing Record 31 of Set 9 | danielskuil
# Processing Record 32 of Set 9 | inuvik
# Processing Record 33 of Set 9 | huarmey
# Processing Record 34 of Set 9 | mount isa
# Processing Record 35 of Set 9 | carmarthen
# Processing Record 36 of Set 9 | aksarka
# Processing Record 37 of Set 9 | bereda
# Processing Record 38 of Set 9 | dabakala
# Processing Record 39 of Set 9 | sembe
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | turukhansk
# Processing Record 42 of Set 9 | sosnogorsk
# Processing Record 43 of Set 9 | sept-iles
# Processing Record 44 of Set 9 | shizunai
# Processing Record 45 of Set 9 | olafsvik
# Processing Record 46 of Set 9 | kamenka
# Processing Record 47 of Set 9 | hastings
# Processing Record 48 of Set 9 | limay
# Processing Record 49 of Set 9 | staritsa
# Processing Record 50 of Set 9 | port macquarie
# Processing Record 1 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 2 of Set 10 | atambua
# Processing Record 3 of Set 10 | simitli
# Processing Record 4 of Set 10 | daokou
# Processing Record 5 of Set 10 | dimbokro
# Processing Record 6 of Set 10 | basco
# Processing Record 7 of Set 10 | dingle
# Processing Record 8 of Set 10 | mandeville
# Processing Record 9 of Set 10 | zhucheng
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | arua
# Processing Record 12 of Set 10 | mtwango
# Processing Record 13 of Set 10 | marienburg
# Processing Record 14 of Set 10 | sa kaeo
# Processing Record 15 of Set 10 | zeya
# Processing Record 16 of Set 10 | grenfell
# Processing Record 17 of Set 10 | davila
# Processing Record 18 of Set 10 | the valley
# Processing Record 19 of Set 10 | sabha
# Processing Record 20 of Set 10 | misratah
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | puerto ayacucho
# Processing Record 23 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 10 | bafoulabe
# Processing Record 25 of Set 10 | kirando
# Processing Record 26 of Set 10 | revda
# Processing Record 27 of Set 10 | lagoa
# Processing Record 28 of Set 10 | axim
# Processing Record 29 of Set 10 | puerto madryn
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | byron bay
# Processing Record 32 of Set 10 | minab
# Processing Record 33 of Set 10 | sendafa
# Processing Record 34 of Set 10 | kutum
# Processing Record 35 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 10 | estevan
# Processing Record 37 of Set 10 | palmas
# Processing Record 38 of Set 10 | zapolyarnyy
# Processing Record 39 of Set 10 | chicontepec
# Processing Record 40 of Set 10 | tucupita
# Processing Record 41 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 10 | coihueco
# Processing Record 43 of Set 10 | bambanglipuro
# Processing Record 44 of Set 10 | berlevag
# Processing Record 45 of Set 10 | cayenne
# Processing Record 46 of Set 10 | hambantota
# Processing Record 47 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 10 | chifeng
# Processing Record 49 of Set 10 | bela
# Processing Record 50 of Set 10 | cap malheureux
# Processing Record 1 of Set 11 | barhi
# Processing Record 2 of Set 11 | santa maria
# Processing Record 3 of Set 11 | sawakin
# Processing Record 4 of Set 11 | concepcion del oro
# Processing Record 5 of Set 11 | saint-jean-port-joli
# Processing Record 6 of Set 11 | walvis bay
# Processing Record 7 of Set 11 | marquette
# Processing Record 8 of Set 11 | alta floresta
# Processing Record 9 of Set 11 | pishin
# Processing Record 10 of Set 11 | issia
# Processing Record 11 of Set 11 | castrillon
# Processing Record 12 of Set 11 | kandalaksha
# Processing Record 13 of Set 11 | lompoc
# Processing Record 14 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 11 | maarianhamina
# Processing Record 16 of Set 11 | northam
# Processing Record 17 of Set 11 | coracora
# Processing Record 18 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | ruteng
# Processing Record 20 of Set 11 | mandalgovi
# Processing Record 21 of Set 11 | kaeo
# Processing Record 22 of Set 11 | moron
# Processing Record 23 of Set 11 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | coolum beach
# Processing Record 25 of Set 11 | norwich
# Processing Record 26 of Set 11 | mehamn
# Processing Record 27 of Set 11 | tepalcatepec
# Processing Record 28 of Set 11 | synya
# Processing Record 29 of Set 11 | lewistown
# Processing Record 30 of Set 11 | salta
# Processing Record 31 of Set 11 | ternovka
# Processing Record 32 of Set 11 | vila
# Processing Record 33 of Set 11 | kainantu
# Processing Record 34 of Set 11 | lata
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | esperance
# Processing Record 37 of Set 11 | tuatapere
# Processing Record 38 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | boende
# Processing Record 40 of Set 11 | kut chap
# Processing Record 41 of Set 11 | umm lajj
# Processing Record 42 of Set 11 | soderhamn
# Processing Record 43 of Set 11 | paita
# Processing Record 44 of Set 11 | krasnogvardeyskoye
# Processing Record 45 of Set 11 | anton lizardo
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | vagay
# Processing Record 48 of Set 11 | alice springs
# Processing Record 49 of Set 11 | ornskoldsvik
# Processing Record 50 of Set 11 | sokoni
# Processing Record 1 of Set 12 | trinidad
# Processing Record 2 of Set 12 | tafo
# Processing Record 3 of Set 12 | ndele
# Processing Record 4 of Set 12 | mondlo
# Processing Record 5 of Set 12 | kysyl-syr
# Processing Record 6 of Set 12 | dukat
# Processing Record 7 of Set 12 | amazar
# Processing Record 8 of Set 12 | sovetskiy
# Processing Record 9 of Set 12 | linxia
# Processing Record 10 of Set 12 | salekhard
# Processing Record 11 of Set 12 | karpogory
# Processing Record 12 of Set 12 | rassvet
# Processing Record 13 of Set 12 | dwarka
# Processing Record 14 of Set 12 | praia da vitoria
# Processing Record 15 of Set 12 | henties bay
# Processing Record 16 of Set 12 | dana point
# Processing Record 17 of Set 12 | nantucket
# Processing Record 18 of Set 12 | yining
# Processing Record 19 of Set 12 | bosaso
# Processing Record 20 of Set 12 | codrington
# Processing Record 21 of Set 12 | presidencia roque saenz pena
# Processing Record 22 of Set 12 | constancia
# Processing Record 23 of Set 12 | pangody
# Processing Record 24 of Set 12 | mwinilunga
# Processing Record 25 of Set 12 | shenjiamen
# Processing Record 26 of Set 12 | pampa
# Processing Record 27 of Set 12 | erenhot
# Processing Record 28 of Set 12 | srandakan
# Processing Record 29 of Set 12 | abha
# Processing Record 30 of Set 12 | bend
# Processing Record 31 of Set 12 | avera
# Processing Record 32 of Set 12 | tautira
# Processing Record 33 of Set 12 | santa quiteria
# Processing Record 34 of Set 12 | havre-saint-pierre
# Processing Record 35 of Set 12 | hamburg
# Processing Record 36 of Set 12 | collierville
# Processing Record 37 of Set 12 | touros
# Processing Record 38 of Set 12 | ardabil
# Processing Record 39 of Set 12 | whitehorse
# Processing Record 40 of Set 12 | la peca
# Processing Record 41 of Set 12 | sun valley
# Processing Record 42 of Set 12 | singkang
# Processing Record 43 of Set 12 | zhanaozen
# Processing Record 44 of Set 12 | san luis
# Processing Record 45 of Set 12 | siguiri
# Processing Record 46 of Set 12 | entre rios
# Processing Record 47 of Set 12 | san vicente de canete
# Processing Record 48 of Set 12 | mkushi
# Processing Record 49 of Set 12 | ziro
# Processing Record 50 of Set 12 | svetlogorsk
# Processing Record 1 of Set 13 | chicama
# Processing Record 2 of Set 13 | nowa sol
# Processing Record 3 of Set 13 | kandrian
# Processing Record 4 of Set 13 | eydhafushi
# Processing Record 5 of Set 13 | arlit
# Processing Record 6 of Set 13 | colchester
# Processing Record 7 of Set 13 | tynda
# Processing Record 8 of Set 13 | kulachi
# Processing Record 9 of Set 13 | miri
# Processing Record 10 of Set 13 | basoko
# Processing Record 11 of Set 13 | dzhebariki-khaya
# Processing Record 12 of Set 13 | bubaque
# Processing Record 13 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 13 | ambatolampy
# Processing Record 15 of Set 13 | taoudenni
# Processing Record 16 of Set 13 | makakilo city
# Processing Record 17 of Set 13 | troitskiy
# Processing Record 18 of Set 13 | valparaiso
# Processing Record 19 of Set 13 | pedernales
# Processing Record 20 of Set 13 | belyy yar
# Processing Record 21 of Set 13 | nouadhibou
# Processing Record 22 of Set 13 | talara
# Processing Record 23 of Set 13 | whitecourt
# Processing Record 24 of Set 13 | san cristobal
# Processing Record 25 of Set 13 | husavik
# Processing Record 26 of Set 13 | loralai
# Processing Record 27 of Set 13 | fairbanks
# Processing Record 28 of Set 13 | fukumitsu
# Processing Record 29 of Set 13 | creston
# Processing Record 30 of Set 13 | harper
# Processing Record 31 of Set 13 | machilipatnam
# Processing Record 32 of Set 13 | manati
# Processing Record 33 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 13 | praia
# Processing Record 35 of Set 13 | boueni
# Processing Record 36 of Set 13 | ayan
# Processing Record 37 of Set 13 | chamba
# Processing Record 38 of Set 13 | virginia beach
# Processing Record 39 of Set 13 | sompeta
# Processing Record 40 of Set 13 | ulaanbaatar
# Processing Record 41 of Set 13 | kudahuvadhoo
# Processing Record 42 of Set 13 | pareora
# Processing Record 43 of Set 13 | waipawa
# Processing Record 44 of Set 13 | ukiah
# Processing Record 45 of Set 13 | dhampur
# Processing Record 46 of Set 13 | santa isabel do rio negro
# Processing Record 47 of Set 13 | pinar del rio
# Processing Record 48 of Set 13 | klamath falls
# Processing Record 49 of Set 13 | guasdualito
# Processing Record 50 of Set 13 | scottsboro
# Processing Record 1 of Set 14 | camacha
# Processing Record 2 of Set 14 | varna
# Processing Record 3 of Set 14 | hovd
# Processing Record 4 of Set 14 | bad neustadt
# City not found. Skipping...
# Processing Record 5 of Set 14 | lorengau
# Processing Record 6 of Set 14 | ahuimanu
# Processing Record 7 of Set 14 | aksay
# Processing Record 8 of Set 14 | itajuba
# Processing Record 9 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 14 | puerto leguizamo
# Processing Record 11 of Set 14 | dariba
# Processing Record 12 of Set 14 | valga
# Processing Record 13 of Set 14 | koumac
# Processing Record 14 of Set 14 | santa cruz de tenerife
# Processing Record 15 of Set 14 | glendive
# Processing Record 16 of Set 14 | gannan
# Processing Record 17 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 14 | fort nelson
# Processing Record 19 of Set 14 | aripuana
# Processing Record 20 of Set 14 | novocheremshansk
# Processing Record 21 of Set 14 | bhuban
# Processing Record 22 of Set 14 | san quintin
# Processing Record 23 of Set 14 | coari
# Processing Record 24 of Set 14 | ngunguru
# Processing Record 25 of Set 14 | batavia
# Processing Record 26 of Set 14 | narrabri
# Processing Record 27 of Set 14 | haines junction
# Processing Record 28 of Set 14 | aksu
# Processing Record 29 of Set 14 | mstera
# Processing Record 30 of Set 14 | romilly-sur-seine
# Processing Record 31 of Set 14 | lucan
# Processing Record 32 of Set 14 | tripoli
# Processing Record 33 of Set 14 | vardo
# Processing Record 34 of Set 14 | callaguip
# Processing Record 35 of Set 14 | atagay
# Processing Record 36 of Set 14 | emerald
# Processing Record 37 of Set 14 | bridlington
# Processing Record 38 of Set 14 | cabuyaro
# Processing Record 39 of Set 14 | mbandaka
# Processing Record 40 of Set 14 | gornopravdinsk
# Processing Record 41 of Set 14 | poum
# Processing Record 42 of Set 14 | tezu
# Processing Record 43 of Set 14 | saint-francois
# Processing Record 44 of Set 14 | norrtalje
# Processing Record 45 of Set 14 | roswell
# Processing Record 46 of Set 14 | chanute
# Processing Record 47 of Set 14 | banda aceh
# Processing Record 48 of Set 14 | bowen
# Processing Record 49 of Set 14 | ketchikan
# Processing Record 50 of Set 14 | inirida
# Processing Record 1 of Set 15 | cerknica
# Processing Record 2 of Set 15 | cabedelo
# Processing Record 3 of Set 15 | mitsamiouli
# Processing Record 4 of Set 15 | itamaraca
# Processing Record 5 of Set 15 | polson
# Processing Record 6 of Set 15 | tazmalt
# Processing Record 7 of Set 15 | casalmaggiore
# Processing Record 8 of Set 15 | fulitun
# City not found. Skipping...
# Processing Record 9 of Set 15 | kochi
# Processing Record 10 of Set 15 | preston
# Processing Record 11 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 15 | jishou
# Processing Record 13 of Set 15 | karratha
# Processing Record 14 of Set 15 | kattivakkam
# Processing Record 15 of Set 15 | gudari
# Processing Record 16 of Set 15 | antigonish
# Processing Record 17 of Set 15 | bermejo
# Processing Record 18 of Set 15 | plavinas
# Processing Record 19 of Set 15 | humaita
# Processing Record 20 of Set 15 | kruisfontein
# Processing Record 21 of Set 15 | mamit
# Processing Record 22 of Set 15 | jinchang
# Processing Record 23 of Set 15 | ponta pora
# Processing Record 24 of Set 15 | celestun
# Processing Record 25 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 15 | tevriz
# Processing Record 28 of Set 15 | monaragala
# Processing Record 29 of Set 15 | gotsu
# Processing Record 30 of Set 15 | lazaro cardenas
# Processing Record 31 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 15 | nome
# Processing Record 33 of Set 15 | bairiki
# Processing Record 34 of Set 15 | takoradi
# Processing Record 35 of Set 15 | kawalu
# Processing Record 36 of Set 15 | sao joao da ponte
# Processing Record 37 of Set 15 | ban nahin
# Processing Record 38 of Set 15 | ganzhou
# Processing Record 39 of Set 15 | batagay-alyta
# Processing Record 40 of Set 15 | qom
# Processing Record 41 of Set 15 | krasnokamensk
# Processing Record 42 of Set 15 | dunbar
# Processing Record 43 of Set 15 | ponca city
# Processing Record 44 of Set 15 | tome-acu
# City not found. Skipping...
# Processing Record 45 of Set 15 | sabang
# Processing Record 46 of Set 15 | manta
# Processing Record 47 of Set 15 | quatre cocos
# Processing Record 48 of Set 15 | yenagoa
# Processing Record 49 of Set 15 | muli
# Processing Record 50 of Set 15 | sergeyevka
# Processing Record 1 of Set 16 | shaoyang
# Processing Record 2 of Set 16 | teguldet
# Processing Record 3 of Set 16 | novo cruzeiro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
# convert the city_data to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kwinana      AU -32.2500  115.7667     61.34       100          91
# 1        Vaitape      PF -16.5167 -151.7500     82.17        74         100
# 2          Vaini      TO -21.2000 -175.2000     75.36        94          75
# 3   Norman Wells      CA  65.2820 -126.8329     30.24        47          20
# 4         Hobart      AU -42.8794  147.3294     52.05        87           0
# 5        Sharjah      AE  25.3573   55.4033     87.78        41           0
# 6        Mataura      NZ -46.1927  168.8643     47.37        77          97
# 7  Marsh Harbour      BS  26.5412  -77.0636     75.54        70         100
# 8     Kaitangata      NZ -46.2817  169.8464     50.45        75          11
# 9     Lavrentiya      RU  65.5833 -171.0000    -12.53        90          77
#
#    Wind Speed Current Description
# 0       16.67     overcast clouds
# 1       19.26     overcast clouds
# 2        0.00       broken clouds
# 3        3.44          few clouds
# 4        8.05           clear sky
# 5        3.44           clear sky
# 6        4.43     overcast clouds
# 7       15.79     overcast clouds
# 8       10.16          few clouds
# 9        2.08       broken clouds

# %%
# Create the export file
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data to CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
