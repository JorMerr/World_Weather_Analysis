# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low= -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 580

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empoty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval ")
print("-------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | necochea
# Processing Record 3 of Set 1 | pacific grove
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | victor harbor
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | vylgort
# City not found. Skipping...
# Processing Record 12 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 1 | flinders
# Processing Record 14 of Set 1 | salo
# Processing Record 15 of Set 1 | grindavik
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | emirdag
# Processing Record 23 of Set 1 | aksarka
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | onguday
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | ndele
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | rocha
# Processing Record 43 of Set 1 | mokhsogollokh
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | manoel urbano
# Processing Record 47 of Set 1 | lazarev
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | ostrovnoy
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | portland
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | vanavara
# Processing Record 10 of Set 2 | lebanon
# Processing Record 11 of Set 2 | rochester
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | tigil
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | tilichiki
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | yumen
# Processing Record 21 of Set 2 | viedma
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | ilhabela
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | wanning
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | pokosnoye
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 2 | comodoro rivadavia
# Processing Record 35 of Set 2 | totma
# Processing Record 36 of Set 2 | grand gaube
# Processing Record 37 of Set 2 | hofn
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | iberia
# Processing Record 40 of Set 2 | palana
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | altay
# Processing Record 43 of Set 2 | molina
# Processing Record 44 of Set 2 | rawson
# Processing Record 45 of Set 2 | port augusta
# Processing Record 46 of Set 2 | lesozavodsk
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | makakilo city
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | safford
# Processing Record 1 of Set 3 | bose
# Processing Record 2 of Set 3 | lukiv
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | russell
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | ereymentau
# Processing Record 8 of Set 3 | upernavik
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | tabuk
# Processing Record 11 of Set 3 | half moon bay
# Processing Record 12 of Set 3 | sibolga
# Processing Record 13 of Set 3 | okha
# Processing Record 14 of Set 3 | beringovskiy
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | show low
# Processing Record 17 of Set 3 | port macquarie
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | oyama
# Processing Record 23 of Set 3 | mezen
# Processing Record 24 of Set 3 | kitimat
# Processing Record 25 of Set 3 | salinopolis
# Processing Record 26 of Set 3 | nara
# Processing Record 27 of Set 3 | sal rei
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | turkmenabat
# Processing Record 30 of Set 3 | monkey bay
# Processing Record 31 of Set 3 | korem
# Processing Record 32 of Set 3 | saint-joseph
# Processing Record 33 of Set 3 | nantucket
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | nagua
# Processing Record 38 of Set 3 | dao
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | alpena
# Processing Record 41 of Set 3 | amahai
# Processing Record 42 of Set 3 | nizwa
# Processing Record 43 of Set 3 | kiruna
# Processing Record 44 of Set 3 | odweyne
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | gravdal
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | bryan
# Processing Record 50 of Set 3 | gamba
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | ouegoa
# Processing Record 3 of Set 4 | narsaq
# Processing Record 4 of Set 4 | ferme-neuve
# Processing Record 5 of Set 4 | stepnogorsk
# Processing Record 6 of Set 4 | saint albans
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | san nicolas
# Processing Record 9 of Set 4 | cowra
# Processing Record 10 of Set 4 | trinidad
# Processing Record 11 of Set 4 | benguela
# Processing Record 12 of Set 4 | libenge
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | shiraz
# Processing Record 15 of Set 4 | kisangani
# Processing Record 16 of Set 4 | vestmanna
# Processing Record 17 of Set 4 | iquique
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | kenai
# Processing Record 20 of Set 4 | kharitonovo
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | colares
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | faya
# Processing Record 28 of Set 4 | bichura
# Processing Record 29 of Set 4 | verkhnevilyuysk
# Processing Record 30 of Set 4 | uthal
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | penzance
# Processing Record 33 of Set 4 | ugoofaaru
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | boiro
# Processing Record 36 of Set 4 | harper
# Processing Record 37 of Set 4 | buraydah
# Processing Record 38 of Set 4 | khandyga
# Processing Record 39 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | cravo norte
# Processing Record 42 of Set 4 | la ronge
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | canutama
# Processing Record 45 of Set 4 | turukhansk
# Processing Record 46 of Set 4 | quatre cocos
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | inuvik
# Processing Record 49 of Set 4 | coihaique
# Processing Record 50 of Set 4 | copiapo
# Processing Record 1 of Set 5 | awash
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | usinsk
# Processing Record 4 of Set 5 | huaihua
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 5 | punta cardon
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | pangnirtung
# Processing Record 9 of Set 5 | chernyshevskiy
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | tiznit
# Processing Record 12 of Set 5 | nuuk
# Processing Record 13 of Set 5 | beipiao
# Processing Record 14 of Set 5 | klenovyy
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | atherton
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | lebu
# Processing Record 19 of Set 5 | chuy
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | dingle
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | le port
# Processing Record 24 of Set 5 | imeni poliny osipenko
# Processing Record 25 of Set 5 | ellsworth
# Processing Record 26 of Set 5 | nishihara
# Processing Record 27 of Set 5 | morro bay
# Processing Record 28 of Set 5 | sarkand
# Processing Record 29 of Set 5 | vrangel
# Processing Record 30 of Set 5 | poya
# Processing Record 31 of Set 5 | nizhneivkino
# Processing Record 32 of Set 5 | verkhoyansk
# Processing Record 33 of Set 5 | mastic beach
# Processing Record 34 of Set 5 | turbat
# Processing Record 35 of Set 5 | corowa
# Processing Record 36 of Set 5 | ponta delgada
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 5 | plettenberg bay
# Processing Record 40 of Set 5 | dunedin
# Processing Record 41 of Set 5 | prince rupert
# Processing Record 42 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 5 | alice springs
# Processing Record 44 of Set 5 | xai-xai
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | krasnokamensk
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | tateyama
# Processing Record 50 of Set 5 | kilindoni
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | tanout
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | port hedland
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | koutiala
# Processing Record 7 of Set 6 | pachino
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | paralimni
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | bud
# Processing Record 13 of Set 6 | khorramshahr
# Processing Record 14 of Set 6 | omaruru
# Processing Record 15 of Set 6 | hailun
# Processing Record 16 of Set 6 | libreville
# Processing Record 17 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 6 | hami
# Processing Record 19 of Set 6 | fare
# Processing Record 20 of Set 6 | mayor pablo lagerenza
# Processing Record 21 of Set 6 | vao
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | chateaudun
# Processing Record 24 of Set 6 | codrington
# Processing Record 25 of Set 6 | ngama
# Processing Record 26 of Set 6 | san cristobal
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | kendari
# Processing Record 29 of Set 6 | tajimi
# Processing Record 30 of Set 6 | tarakan
# Processing Record 31 of Set 6 | bubaque
# Processing Record 32 of Set 6 | roma
# Processing Record 33 of Set 6 | ichinohe
# Processing Record 34 of Set 6 | patna
# Processing Record 35 of Set 6 | wonthaggi
# Processing Record 36 of Set 6 | kushmurun
# Processing Record 37 of Set 6 | alta floresta
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | adet
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | sur
# Processing Record 42 of Set 6 | jinji
# Processing Record 43 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 6 | acari
# Processing Record 45 of Set 6 | roebourne
# Processing Record 46 of Set 6 | luanda
# Processing Record 47 of Set 6 | syedove
# Processing Record 48 of Set 6 | north branch
# Processing Record 49 of Set 6 | tautira
# Processing Record 50 of Set 6 | kayes

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature " + time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs humidity.
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity " + time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs humidity.
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) " + time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs humidity.
plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed " + time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values, "r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df["Lat"] >= 0

# %%
# Create Northern Hemisphere DataFrame.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
northern_hemi_df.head()

# %%
# Create Southern Hemisphere DataFrame.
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <= 0)]
southern_hemi_df.head()

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemishere \
                      for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere.
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\
                      for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear Regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\
                      for % Humidity', '% Humidity', (40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \
                      for % Humidity', "% Humidity", (-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere \
                      for % Cloudiness', '% Cloudiness', (0,100))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \
                      for % Cloudiness', '% Cloudiness', (0,100))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere \
                      for Wind Speed', 'Wind Speed', (40,35))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \
                      for Wind Speed', 'Wind Speed', (-50,35))
